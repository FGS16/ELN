# %%
#DNA invader displaces an RNA incumbent from a complex with a DNA template strand
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

g = 6 
b = 20 

R = 1.987/1000 #define universal gas constant in kcal/(K.mol)
temp = 298.15 #define temperature in Kelvin
dGassoc = 1.90
dGvol = 9.95
dGbp = -1.7
dGp = 0
dGrd = - 1
dGs = 5.3
k_bi = 3*10**6 #define the rate constant for bimolecular transitions
k_uni = 7.5*10**7 #define the rate constant for unimolecular transitions


dGboxA = 0
dGboxB1 = dGassoc + dGvol + dGbp
dGboxBr = np.empty(g)
for to in range(g): 
    dGboxBr [to] = dGboxB1 + dGbp*to
dGboxC1 = dGassoc + dGvol + dGbp*g
dGboxCh1 = dGboxC1 + dGp + dGs - dGrd
dGboxCr = np.empty(b-1)
dGboxCh = np.empty(b-1)
for br in range(b-1): 
    dGboxCh[br] = dGboxCh1 - dGrd*br
    dGboxCr[br] = dGboxCh[br] - dGs
dGboxD = dGboxCh1 - dGs - (dGrd)*(b-2)
dGboxE = dGboxD - dGvol - dGassoc
dGboxF = dGboxE + dGbp

dGboxC = np.empty(b*2)
dGboxC = [i for j in zip(dGboxCh, dGboxCr) for i in j]
dGboxAB1 = dGboxAB1 = [dGboxA, dGboxB1] 
dGboxC1Ch1 = [dGboxC1, dGboxCh1]

plt.figure()
plt.plot(range(-g,-g+2), dGboxAB1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black' )
plt.plot(range(-g+1,1), dGboxBr, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
plt.plot(np.arange(0, 1, 0.5), dGboxC1Ch1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
plt.plot(np.arange(0.5, b-0.5, 0.5), dGboxC, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
plt.plot([b-1, b-0.5, b], [dGboxD, dGboxE, dGboxF],'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
plt.xlabel('Number of strand displacement steps')
plt.ylabel('\u0394Gbox(kcal/mol)')
plt.title('DNA displacing RNA free energy landscape for toehold length ' + str(g))
plt.show()

# %%
for g in range(1, 16):
    dGboxA = 0
    dGboxB1 = dGassoc + dGvol + dGbp
    dGboxBr = np.empty(g)
    for to in range(g): 
        dGboxBr [to] = dGboxB1 + dGbp*to
    dGboxC1 = dGassoc + dGvol + dGbp*g
    dGboxCh1 = dGboxC1 + dGp + dGs - dGrd
    dGboxCr = np.empty(b-1)
    dGboxCh = np.empty(b-1)
    for br in range(b-1): 
        dGboxCh[br] = dGboxCh1 - dGrd*br
        dGboxCr[br] = dGboxCh[br] - dGs
    dGboxD = dGboxCh1 - dGs - (dGrd)*(b-2)
    dGboxE = dGboxD - dGvol - dGassoc
    dGboxF = dGboxE + dGbp

    dGboxC = np.empty(b*2)
    dGboxC = [i for j in zip(dGboxCh, dGboxCr) for i in j]
    dGboxAB1 = dGboxAB1 = [dGboxA, dGboxB1] 
    dGboxC1Ch1 = [dGboxC1, dGboxCh1]

    plt.figure()
    plt.plot(range(-g,-g+2), dGboxAB1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black' )
    plt.plot(range(-g+1,1), dGboxBr, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
    plt.plot(np.arange(0, 1, 0.5), dGboxC1Ch1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
    plt.plot(np.arange(0.5, b-0.5, 0.5), dGboxC, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
    plt.plot([b-1, b-0.5, b], [dGboxD, dGboxE, dGboxF],'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
    plt.xlabel('Number of strand displacement steps')
    plt.ylabel('\u0394Gbox(kcal/mol)')
    plt.title('DNA displacing RNA free energy landscape for toehold length ' + str(g))
    plt.show()

# %%
g = 6
for b in range(1, 21):
    dGboxA = 0
    dGboxB1 = dGassoc + dGvol + dGbp
    dGboxBr = np.empty(g)
    for to in range(g): 
        dGboxBr [to] = dGboxB1 + dGbp*to
    dGboxC1 = dGassoc + dGvol + dGbp*g
    dGboxCh1 = dGboxC1 + dGp + dGs - dGrd
    dGboxCr = np.empty(b-1)
    dGboxCh = np.empty(b-1)
    for br in range(b-1): 
        dGboxCh[br] = dGboxCh1 - dGrd*br
        dGboxCr[br] = dGboxCh[br] - dGs
    dGboxD = dGboxCh1 - dGs - (dGrd)*(b-2)
    if b==1:
        dGboxE = dGboxC1 - dGvol - dGassoc
    else:
        dGboxE = dGboxD - dGvol - dGassoc
    dGboxF = dGboxE + dGbp
    
    dGboxC = np.empty(b*2)
    dGboxC = [i for j in zip(dGboxCh, dGboxCr) for i in j]
    dGboxAB1 = dGboxAB1 = [dGboxA, dGboxB1] 
    dGboxC1Ch1 = [dGboxC1, dGboxCh1]

    plt.figure()
    if b == 1: 
        plt.plot(range(-g,-g+2), dGboxAB1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black' )
        plt.plot(range(-g+1,1), dGboxBr, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.plot(np.arange(0, 1, 0.5), [dGboxC1, dGboxE], 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        #plt.plot(np.arange(0.5, b-0.5, 0.5), dGboxC, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.plot([b-0.5, b], [dGboxE, dGboxF],'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.xlabel('Number of strand displacement steps')
        plt.ylabel('\u0394Gbox(kcal/mol)')
        plt.title('DNA displacing RNA free energy landscape for branch migration domain length ' + str(b))
        plt.show()
    else: 
        plt.plot(range(-g,-g+2), dGboxAB1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black' )
        plt.plot(range(-g+1,1), dGboxBr, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.plot(np.arange(0, 1, 0.5), dGboxC1Ch1, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.plot(np.arange(0.5, b-0.5, 0.5), dGboxC, 'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.plot([b-1, b-0.5, b], [dGboxD, dGboxE, dGboxF],'k--', marker = 'o', markerfacecolor = 'black', markeredgecolor = 'black')
        plt.xlabel('Number of strand displacement steps')
        plt.ylabel('\u0394Gbox(kcal/mol)')
        plt.title('DNA displacing RNA free energy landscape for branch migration domain length ' + str(b))
        plt.show()
